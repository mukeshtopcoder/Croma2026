# %%
NLP :- Natural Language Processing

NLP Basics
- Tokenization (divide sentence in words)
- Stop Words Removal
- Stemming  (running => run  , studies => studi) it works fast 
- Lemmatization (running => run  ) slow but accurate
- Part of speech tagging

Popular Libraries NLP
NLTK
spaCy


who is the prime minister of India?
best => good

# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\THIS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\THIS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = "Vishal is learning Natural Language Processing"

# %%
# Tokenization
words = nltk.word_tokenize(text) 
words
# Out:
# ['Vishal', 'is', 'learning', 'Natural', 'Language', 'Processing']

# %%
# POS Tagging
pos_tag = nltk.pos_tag(words)
pos_tag
# Out:
# [('Vishal', 'NNP'),
#  ('is', 'VBZ'),
#  ('learning', 'VBG'),
#  ('Natural', 'NNP'),
#  ('Language', 'NNP'),
#  ('Processing', 'NNP')]

# %%
# NNP :-  Proper Noun
# VBZ :-  Verb
# VBG :-  Verb (ing)
